# %% [markdown]
# ## Imports

# %%
from __future__ import division

import h5py
import numpy as np
import pandas as pd
from scipy import stats

from statsmodels.graphics.gofplots import qqplot_2samples
import statsmodels.api as sm

# %% [markdown]
# ## Empirical data

# %%
storage = h5py.File('storage/flightsTest.h5', 'r')
historical = h5py.File('storage/flightsTrain.h5', 'r')

# %% [markdown]
# ## Tests

# %%
def get_ticketPrices(dataset, flyFrom, flyTo):
    """
    returns cleaned up ticketPrices AND meanTicketPrice in whole $'s (for sell-outs)
    
    dataset: data to get prices from (historical/current)
    flyFrom: outbound airport
    flyTo: inbound airport
    """
    ticketPrices = pd.DataFrame(dataset[flyFrom][flyTo][:,1:43], dtype=np.float64)
    ticketPrices[ticketPrices == 0] = np.nan
    ticketPrices = ticketPrices.dropna(thresh=int(42*2/3)).ffill(axis=1)  # drop everythings that has less than 2/3 avilable data
    meanTicketPrice = ticketPrices.mean().mean()
    return ticketPrices, meanTicketPrice

# %%
flyFrom = 'ATL'
flyTo = 'MCO'

b, _ = get_ticketPrices(storage, flyFrom, flyTo)
b = np.log(b)
bRet = (b.T.shift(3).T-b).values
bb = bRet[np.logical_not(np.isnan(bRet))]
data = bb

# %%
m = 3

data = []

for flyFrom in storage.keys():
    for flyTo in storage[flyFrom].keys():
        b, _ = get_ticketPrices(storage, flyFrom, flyTo)
        b = np.log(b)
        bRet = (b.T.shift(m).T-b).values
        bb = bRet[np.logical_not(np.isnan(bRet))]
        data += list(bb)
data = np.array(data)

# %%
bs = 70
n, bins, _ = hist(data, normed=True, bins=bs)
loc, scale = stats.norm.fit(data)

mbins = (bins[1:]+bins[:-1])/2
myNorm = stats.norm.pdf(mbins, loc, scale)
_ = plot(mbins, myNorm)
show()
stats.chisquare(n, myNorm)
# Out:
# (26.083290148792322, 0.99999941177924812)

# %%
stats.test

# %%
myNorm[33]
# Out:
# 2.5665007856435422

# %%
(a[1:]+a[:-1])/2
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5])

# %%
figsize(12, 8)

for flyFrom in historical.keys():
    for flyTo in historical[flyFrom].keys():
        b, _ = get_ticketPrices(storage, flyFrom, flyTo)
        b = np.log(b)
        bRet = (b.T.shift(1).T-b)
        fig = figure()
        _ = bRet.boxplot()
        title(flyFrom +  flyTo)

# %%
pd.tools.plotting.lag_plot(bRet)

# %%
a.shape
# Out:
# (314969,)

# %%
stats.kstest(bb, 'logistic')
# Out:
# (0.68014981852712619, 0.0)

# %%
stats.ks_2samp(bb, bRet.flatten())
# Out:
# (0.024376417233560099, 0.0039293984556445323)

# %%
print stats.probplot(bb.values.flatten(), dist="logistic", plot=pylab)
# Out:
# ((array([-13.05185753, -12.16506082, -11.69858931, ...,  11.69858931,
#         12.16506082,  13.05185753]), array([-2.09990646, -2.08679889, -2.02574383, ...,         nan,
#                nan,         nan])), (nan, nan, nan))

# %%
print stats.probplot(bb, dist="logistic", plot=pylab)
# Out:
# ((array([-12.99132766, -12.10453076, -11.63805906, ...,  11.63805906,
#         12.10453076,  12.99132766]), array([-1.26285767, -1.22222019, -1.22222019, ...,  1.3166333 ,
#         1.3166333 ,  1.3166333 ])), (0.05206904561107812, 0.02041731073000826, 0.87535828531847937))

# %%
stats.kstest(bb, 'norm')
# Out:
# (0.45191495126737413, 0.0)

# %%
bins, n, _ = hist(bb, bins=100, normed=True)
ff = stats.norm.fit(bb)
y = mlab.normpdf(bins, ff[0], ff[1])
plot(bins, y)

# %%
np.mean(bb)
# Out:
# 0.0056950309837532813

# %%
stats.gaussian_kde(bb)

# %%
x = bb

density = stats.gaussian_kde(x)
xgrid = np.linspace(x.min(), x.max(), 75)
plt.hist(x, bins=75, normed=True)
plt.plot(xgrid, density(xgrid), 'r-')

# %%
density.scotts_factor()
# Out:
# 0.16916738049970004

# %%
fig = qqplot_2samples(aRet, np.random.choice(bRet, aRet.shape[0]))
_ = title("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7a2eb7d0f605> in <module>()
# ----> 1 fig = qqplot_2samples(aRet, np.random.choice(bRet, aRet.shape[0]))
#       2 _ = title("hello")
#
# /usr/lib/python2.7/site-packages/numpy/random/mtrand.so in mtrand.RandomState.choice (numpy/random/mtrand/mtrand.c:7258)()
#
# ValueError: a must be 1-dimensional

# %%
fig.

# %%
a = np.random.normal(loc=np.mean(aRet), scale=np.std(aRet), size=aRet.shape[0])

stats.kstest(bRet, 'norm')
# Out:
# (0.33774801602672355, 0.0)

# %%
stats.lognorm._cdf(

# %%
_ = hist(aRet, bins=100)
_ = hist(a, bins=100)
ylim(0,10000)
# Out:
# (0, 10000)

# %%
x = np.arange(0, 1, 0.01)
plot(x, stats.norm.cdf(x))

# %%
stats.norm.rvs(10000, 1000)
# Out:
# 8720.410839518154

# %%
r = np.arange(-10, 10, 0.001)
# Mean = 0, SD = 2.
plot(r, stats.norm.pdf(r,0,2))
yscale('linear')
